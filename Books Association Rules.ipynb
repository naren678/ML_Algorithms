# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("C:\\Users\\User\\Downloads\\book.csv")

# %%
from mlxtend.frequent_patterns import apriori,association_rules

# %%
frequent_itemsets = apriori(data,min_support=0.005,use_colnames=True)
rules=association_rules(frequent_itemsets,metric='lift',min_threshold=1)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (YouthBks)  (ChildBks)              0.2475              0.4230    0.165
# 1  (ChildBks)  (YouthBks)              0.4230              0.2475    0.165
# 2   (CookBks)  (ChildBks)              0.4310              0.4230    0.256
# 3  (ChildBks)   (CookBks)              0.4230              0.4310    0.256
# 4  (DoItYBks)  (ChildBks)              0.2820              0.4230    0.184
#
#    confidence      lift  leverage  conviction
# 0    0.666667  1.576044  0.060308    1.731000
# 1    0.390071  1.576044  0.060308    1.233750
# 2    0.593968  1.404179  0.073687    1.421069
# 3    0.605201  1.404179  0.073687    1.441240
# 4    0.652482  1.542511  0.064714    1.660347

# %%
rules[(rules['lift']>= 6) & (rules['confidence'] >= 0.8)]
# Out:
#                                             antecedents  \
# 562                                 (ItalArt, YouthBks)
# 719                                (ItalAtlas, CookBks)
# 725                                  (ItalArt, CookBks)
# 845                                 (ItalArt, DoItYBks)
# 929                                   (ItalArt, RefBks)
# ...                                                 ...
# 35132  (DoItYBks, ItalAtlas, CookBks, ItalArt, GeogBks)
# 35133   (DoItYBks, ItalAtlas, ArtBks, ItalArt, GeogBks)
# 35180              (ItalArt, RefBks, DoItYBks, GeogBks)
# 35195            (ItalAtlas, GeogBks, ArtBks, DoItYBks)
# 35196           (ItalArt, ItalAtlas, GeogBks, DoItYBks)
#
#                                   consequents  antecedent support  \
# 562                                (ItalCook)              0.0230
# 719                                (ItalCook)              0.0285
# 725                                (ItalCook)              0.0410
# 845                                (ItalCook)              0.0300
# 929                                (ItalCook)              0.0200
# ...                                       ...                 ...
# 35132              (ItalCook, RefBks, ArtBks)              0.0050
# 35133             (ItalCook, RefBks, CookBks)              0.0055
# 35180  (ArtBks, ItalAtlas, ItalCook, CookBks)              0.0060
# 35195    (ItalArt, ItalCook, RefBks, CookBks)              0.0055
# 35196     (ArtBks, ItalCook, RefBks, CookBks)              0.0055
#
#        consequent support  support  confidence       lift  leverage  \
# 562                0.1135   0.0190    0.826087   7.278299  0.016390
# 719                0.1135   0.0230    0.807018   7.110287  0.019765
# 725                0.1135   0.0375    0.914634   8.058451  0.032847
# 845                0.1135   0.0250    0.833333   7.342144  0.021595
# 929                0.1135   0.0160    0.800000   7.048458  0.013730
# ...                   ...      ...         ...        ...       ...
# 35132              0.0235   0.0050    1.000000  42.553191  0.004882
# 35133              0.0465   0.0050    0.909091  19.550342  0.004744
# 35180              0.0130   0.0050    0.833333  64.102564  0.004922
# 35195              0.0160   0.0050    0.909091  56.818182  0.004912
# 35196              0.0235   0.0050    0.909091  38.684720  0.004871
#
#        conviction
# 562      5.097375
# 719      4.593682
# 725     10.384714
# 845      5.319000
# 929      4.432500
# ...           ...
# 35132         inf
# 35133   10.488500
# 35180    5.922000
# 35195   10.824000
# 35196   10.741500
#
# [1198 rows x 9 columns]
